# %% [markdown]
# ### 1.5 Practicing to find an optimal method to solve problems with scikit-learn
# **Iris Data**

# %%
### IRIS 
from sklearn.datasets import load_iris
data = load_iris()
data.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
import pandas as pd
import seaborn as sns
import numpy as no
import matplotlib.pyplot as plt

iris = pd.DataFrame(data = data.data, columns = data.feature_names)
print(iris)

feature = pd.DataFrame(data = data.data, columns = data.feature_names)
target = pd.DataFrame(data = data.target, columns = ["species"])
print(target)

iris = pd.concat([feature, target], axis = 1)
iris.rename({"sepal length (cm)":"sepal length",  "sepal width (cm)":"sepal width",
            "petal length (cm)":"petal length",  "petal width (cm)":"petal width"}, axis = 1, inplace = True)
iris.columns
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
#      species
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ..       ...
# 145        2
# 146        2
# 147        2
# 148        2
# 149        2
#
# [150 rows x 1 columns]
# Index(['sepal length', 'sepal width', 'petal length', 'petal width',
#        'species'],
#       dtype='object')

# %%
# Q: Change the target value (“Species”) to {0 -> setosa, 1 -> versicolor, 2 -> virginica} using the map function.  

class_mapping = { 0:"setosa",  1:"versicolor",  2:"virginica" }
iris["species"] = iris["species"].map(class_mapping)
print(iris)
# Out:
#      sepal length  sepal width  petal length  petal width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Q: Check the number of missing values per attribute

iris.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# species         0
# dtype: int64

# %%
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.corr()
# Out:
# C:\Users\Nando\AppData\Local\Temp\ipykernel_1784\2141086772.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal length  sepal width  petal length  petal width
# sepal length      1.000000    -0.117570      0.871754     0.817941
# sepal width      -0.117570     1.000000     -0.428440    -0.366126
# petal length      0.871754    -0.428440      1.000000     0.962865
# petal width       0.817941    -0.366126      0.962865     1.000000

# %%
iris.groupby("species").size()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# dtype: int64

# %%
# plotting a scatterplot using seaborn 
sns.scatterplot(data=iris, x='sepal length', y='petal width', hue='species') 
plt.plot()
# Out:
# []

# %%
# plotting a pairplot using seaborn 
sns.pairplot(iris, hue ="species")
plt.plot()
# Out:
# []

# %% [markdown]
# **Q: What can you observe?  Check the distribution for the different classes, their separability for the different attributes, etc.**
#
# Setosa is aggregated by clearly being deviated from other classes. Classification is possible by drawing an imaginary line, and setosa will be classified as a linear model. For versicolor and virginica, it seems to be difficult to classify them by drawing a line because they are mixed in the graph complete with the sepal_width and sepal_length features. However, even it seems a little vague, they can be classified in other graphs.

# %%
# Q: Split the data 

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(iris.iloc[:, :-1], iris.iloc[:,-1], test_size = 0.33, random_state = 42)
print(X_test)
# Out:
#      sepal length  sepal width  petal length  petal width
# 73            6.1          2.8           4.7          1.2
# 18            5.7          3.8           1.7          0.3
# 118           7.7          2.6           6.9          2.3
# 78            6.0          2.9           4.5          1.5
# 76            6.8          2.8           4.8          1.4
# 31            5.4          3.4           1.5          0.4
# 64            5.6          2.9           3.6          1.3
# 141           6.9          3.1           5.1          2.3
# 68            6.2          2.2           4.5          1.5
# 82            5.8          2.7           3.9          1.2
# 110           6.5          3.2           5.1          2.0
# 12            4.8          3.0           1.4          0.1
# 36            5.5          3.5           1.3          0.2
# 9             4.9          3.1           1.5          0.1
# 19            5.1          3.8           1.5          0.3
# 56            6.3          3.3           4.7          1.6
# 104           6.5          3.0           5.8          2.2
# 69            5.6          2.5           3.9          1.1
# 55            5.7          2.8           4.5          1.3
# 132           6.4          2.8           5.6          2.2
# 29            4.7          3.2           1.6          0.2
# 127           6.1          3.0           4.9          1.8
# 26            5.0          3.4           1.6          0.4
# 128           6.4          2.8           5.6          2.1
# 131           7.9          3.8           6.4          2.0
# 145           6.7          3.0           5.2          2.3
# 108           6.7          2.5           5.8          1.8
# 143           6.8          3.2           5.9          2.3
# 45            4.8          3.0           1.4          0.3
# 30            4.8          3.1           1.6          0.2
# 22            4.6          3.6           1.0          0.2
# 15            5.7          4.4           1.5          0.4
# 65            6.7          3.1           4.4          1.4
# 11            4.8          3.4           1.6          0.2
# 42            4.4          3.2           1.3          0.2
# 146           6.3          2.5           5.0          1.9
# 51            6.4          3.2           4.5          1.5
# 27            5.2          3.5           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# 32            5.2          4.1           1.5          0.1
# 142           5.8          2.7           5.1          1.9
# 85            6.0          3.4           4.5          1.6
# 86            6.7          3.1           4.7          1.5
# 16            5.4          3.9           1.3          0.4
# 10            5.4          3.7           1.5          0.2
# 81            5.5          2.4           3.7          1.0
# 133           6.3          2.8           5.1          1.5
# 137           6.4          3.1           5.5          1.8
# 75            6.6          3.0           4.4          1.4
# 109           7.2          3.6           6.1          2.5

# %%
# Alg. selection

from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(criterion = "gini", splitter = "best", max_depth = 5)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
model.score(X_test, y_test)
# Out:
# 0.98

# %%
from sklearn.metrics import accuracy_score

preds = model.predict(X_test)
accuracy_score(preds, y_test)
# Out:
# 0.98

# %%
import numpy as np
from sklearn.model_selection import cross_val_score, KFold

cv = KFold(n_splits = 10, shuffle = True, random_state = 42)
results = cross_val_score(model, X_train, y_train, cv = cv)
fin_result = np.mean(results)
fin_result
results
# Out:
# array([0.9, 1. , 0.8, 1. , 0.8, 1. , 1. , 0.9, 1. , 1. ])

# %%
for i, _ in enumerate(results):
      print(str(i) + "th cross validation score: " + repr(_))
print("Final cross validation score: " + repr(fin_result))
# Out:
# 0th cross validation score: 0.9
# 1th cross validation score: 1.0
# 2th cross validation score: 0.8
# 3th cross validation score: 1.0
# 4th cross validation score: 0.8
# 5th cross validation score: 1.0
# 6th cross validation score: 1.0
# 7th cross validation score: 0.9
# 8th cross validation score: 1.0
# 9th cross validation score: 1.0
# Final cross validation score: 0.9400000000000001

# %%
cv = KFold(n_splits = 10, shuffle = True, random_state = 42)
results = cross_val_score(model, iris.iloc[:, :-1], iris.iloc[:,-1], cv = cv)
fin_result = np.mean(results)

for i, _ in enumerate(results):
      print(str(i) + "th cross validation score: " + repr(_))
print("Final cross validation score: " + repr(fin_result))
# Out:
# 0th cross validation score: 1.0
# 1th cross validation score: 1.0
# 2th cross validation score: 1.0
# 3th cross validation score: 0.9333333333333333
# 4th cross validation score: 1.0
# 5th cross validation score: 0.8666666666666667
# 6th cross validation score: 0.8666666666666667
# 7th cross validation score: 1.0
# 8th cross validation score: 0.8666666666666667
# 9th cross validation score: 0.9333333333333333
# Final cross validation score: 0.9466666666666667

# %%
# Learning Curves


# !pip install scikit-plot
# !pip install scipy matplotlib scikit-learn

import scikitplot as skplt
import matplotlib.pyplot as plt
skplt.estimators.plot_learning_curve(model,X_train, y_train, figsize = (6,6))
plt.show()

# %%
# Model Optimisation Strategy

estimator = DecisionTreeClassifier()
from sklearn.model_selection import GridSearchCV

parameters = {"max_depth" : [4,6,8,10,12]}
model2 = GridSearchCV(estimator = estimator,
                      param_grid = parameters,
                      cv = KFold(10), verbose = 1,
                      n_jobs = -1, refit = True)
model2.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 5 candidates, totalling 50 fits
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=False),
#              estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [4, 6, 8, 10, 12]}, verbose=1)

# %%
model2.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
model2.best_params_
# Out:
# {'max_depth': 4}

# %%
model2.best_score_
# Out:
# 0.9299999999999999

# %%
# Evaluation Criteria and model evaluation

from sklearn.metrics import accuracy_score
pred = model2.predict(X_test)
pred
# Out:
# array(['versicolor', 'setosa', 'virginica', 'versicolor', 'versicolor',
#        'setosa', 'versicolor', 'virginica', 'versicolor', 'versicolor',
#        'virginica', 'setosa', 'setosa', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'virginica', 'setosa',
#        'virginica', 'setosa', 'virginica', 'virginica', 'virginica',
#        'virginica', 'virginica', 'setosa', 'setosa', 'setosa', 'setosa',
#        'versicolor', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'setosa', 'setosa', 'setosa', 'virginica', 'versicolor',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'versicolor',
#        'virginica', 'versicolor', 'virginica'], dtype=object)

# %%
accuracy_score(y_test, pred)
# Out:
# 0.98

# %%
# Limitations of accuracy

from sklearn.metrics import confusion_matrix
pred=model.predict(X_test)
confusion_matrix(y_test, pred)

# %%
from sklearn.metrics import precision_score
precisions = precision_score(y_test, pred, average = None)
precisions
# array([1.    , 0.9375, 1.    ])

for target, score in zip(data.target_names, precisions):
        print(f"{target} precion: {score}")

# %%
from sklearn.metrics import recall_score
recalls = recall_score(y_test, pred, average = None)
recalls

for target, score in zip(data.target_names, recalls):
        print(f"{target} precion: {score}")

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred))
